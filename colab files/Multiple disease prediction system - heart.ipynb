# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)  
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Processing

# %%
heart_data = pd.read_csv('C:/Users/SAKSHI/OneDrive/Desktop/.vscode/Machine Learning/dataset/heart.csv')

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.tail()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 93   59    1   0       140   177    0        1      162      1      0.0
# 94   57    1   2       128   229    0        0      150      0      0.4
# 95   61    1   0       120   260    0        1      140      1      3.6
# 96   39    1   0       118   219    0        1      140      0      1.2
# 97   61    0   0       145   307    0        0      146      1      1.0
#
#     slope  ca  thal  target
# 93      2   1     3       0
# 94      1   1     3       0
# 95      1   1     3       0
# 96      1   0     3       0
# 97      1   0     3       0

# %%
heart_data.shape
# Out:
# (98, 14)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       98 non-null     int64
#  1   sex       98 non-null     int64
#  2   cp        98 non-null     int64
#  3   trestbps  98 non-null     int64
#  4   chol      98 non-null     int64
#  5   fbs       98 non-null     int64
#  6   restecg   98 non-null     int64
#  7   thalach   98 non-null     int64
#  8   exang     98 non-null     int64
#  9   oldpeak   98 non-null     float64
#  10  slope     98 non-null     int64
#  11  ca        98 non-null     int64
#  12  thal      98 non-null     int64
#  13  target    98 non-null     int64
# dtypes: float64(1), int64(13)
# memory usage: 10.8 KB

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_data.describe()
# Out:
#              age        sex         cp    trestbps        chol        fbs  \
# count  98.000000  98.000000  98.000000   98.000000   98.000000  98.000000
# mean   54.693878   0.734694   1.010204  133.367347  246.867347   0.132653
# std     8.171371   0.443766   1.050232   15.641860   49.190066   0.340943
# min    37.000000   0.000000   0.000000  104.000000  164.000000   0.000000
# 25%    49.000000   0.000000   0.000000  120.000000  213.750000   0.000000
# 50%    56.000000   1.000000   1.000000  130.000000  239.000000   0.000000
# 75%    60.000000   1.000000   2.000000  141.500000  272.250000   0.000000
# max    71.000000   1.000000   3.000000  180.000000  417.000000   1.000000
#
#          restecg     thalach      exang    oldpeak      slope         ca  \
# count  98.000000   98.000000  98.000000  98.000000  98.000000  98.000000
# mean    0.448980  150.969388   0.336735   1.302041   1.357143   0.622449
# std     0.499947   19.979605   0.475023   1.148282   0.677320   0.891140
# min     0.000000   99.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000  140.250000   0.000000   0.400000   1.000000   0.000000
# 50%     0.000000  153.000000   0.000000   1.200000   1.000000   0.000000
# 75%     1.000000  163.000000   1.000000   1.800000   2.000000   1.000000
# max     1.000000  188.000000   1.000000   6.200000   2.000000   3.000000
#
#             thal     target
# count  98.000000  98.000000
# mean    2.367347   0.500000
# std     0.632256   0.502571
# min     0.000000   0.000000
# 25%     2.000000   0.000000
# 50%     2.000000   0.500000
# 75%     3.000000   1.000000
# max     3.000000   1.000000

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    49
# 0    49
# Name: count, dtype: int64

# %% [markdown]
# 1 --> Defective Heart
#
# 0 --> Healthy Heart

# %% [markdown]
# Splitting the Features and Target

# %%
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# %%
print(X)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# ..  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 93   59    1   0       140   177    0        1      162      1      0.0
# 94   57    1   2       128   229    0        0      150      0      0.4
# 95   61    1   0       120   260    0        1      140      1      3.6
# 96   39    1   0       118   219    0        1      140      0      1.2
# 97   61    0   0       145   307    0        0      146      1      1.0
#
#     slope  ca  thal
# 0       0   0     1
# 1       0   0     2
# 2       2   0     2
# 3       2   0     2
# 4       2   0     2
# ..    ...  ..   ...
# 93      2   1     3
# 94      1   1     3
# 95      1   1     3
# 96      1   0     3
# 97      1   0     3
#
# [98 rows x 13 columns]

# %%
print(Y)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 93    0
# 94    0
# 95    0
# 96    0
# 97    0
# Name: target, Length: 98, dtype: int64

# %% [markdown]
# Splitting the Data into Training data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (98, 13) (78, 13) (20, 13)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# c:\Users\SAKSHI\anaconda3\envs\DiseasePrediction\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.8461538461538461

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.95

# %% [markdown]
# Building a Predictive System

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)


input_data_as_numpy_array= np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [0]
# The Person does not have a Heart Disease
# c:\Users\SAKSHI\anaconda3\envs\DiseasePrediction\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Saving the trained model

# %%
import pickle

# %%
filename = 'heart_disease_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('heart_disease_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# age
# sex
# cp
# trestbps
# chol
# fbs
# restecg
# thalach
# exang
# oldpeak
# slope
# ca
# thal
